# %%
import json
import math
import pathlib
import webbrowser

import osmutils
import uii

import responses
import pandas as pd
import geopandas
import googlemaps

from googlemaps.maps import StaticMapMarker
from googlemaps.maps import StaticMapPath

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import warnings; warnings.filterwarnings('ignore', 'GeoSeries.notna', UserWarning)

# %%
def _get_clean_train_filepaths(train_data_dir):
    clean_train_files = []
    main_train_dir_path = pathlib.Path(
        pathlib.PurePath(pathlib.Path.cwd()).parent, pathlib.Path('train'))
    
    for train_dir in [x for x in main_train_dir_path.iterdir()
                      if x.is_dir() and '.' not in x.name]:
        clean_dir = train_dir / str(train_data_dir)
        for clean_train_file in [x for x in clean_dir.iterdir() 
                                 if not x.is_dir()]:
            clean_train_files.append(str(clean_train_file))
    
    return clean_train_files


def get_pd_dataframe_from_dir(train_data_dir):
    clean_train_files = _get_clean_train_filepaths(train_data_dir)

    # setup pandas dataframe
    df = pd.concat([pd.read_csv(x) for x in clean_train_files], sort=False)

    return df

# %%
ue_logs = []
with open('routes/A_D/A_D_sony1_1min_10s_server.txt') as f:
    for line in f:
        if line[0] == 'b' and line[1] == '\'':
            ue_log = json.loads(line[2:-4])
            ue_logs.append(ue_log)

# %%
geopandas.options.display_precision = 16
j, k = osmutils.processUELocation(ue_logs[1]['gps']['lat'], ue_logs[1]['gps']['lon'], ue_logs[1]['gps']['acc'])

gdf = osmutils.get_road_segment_gdf(j)
print(gdf)
for i in gdf['geometry']:
    print(type(i))
    print(i)
    print(str(list(i.exterior.coords)))
    print(str(list(i.exterior.coords)).replace('(', '{lat: ').replace(')', '}').replace('}, {', 'x').replace(', ', ', lng: ').replace('x', '}, {'))
    
gdf.plot()
# Out:
#                                              geometry       polygon_name  \
# 0   POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg1
# 1   POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg2
# 2   POLYGON ((24.7891225762456529 120.999806675464...  way_seg1_way_seg3
# 3   POLYGON ((24.7890794237543446 120.999807924535...  way_seg2_way_seg4
# 4   POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg1
# 5   POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg2
# 6   POLYGON ((24.7891172280992542 120.999791625273...  way_seg1_way_seg3
# 7   POLYGON ((24.7890847718991125 120.999822974721...  way_seg2_way_seg4
# 8   POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg1
# 9   POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg2
# 10  POLYGON ((24.7890895668732192 120.999827464859...  way_seg1_way_seg3
# 11  POLYGON ((24.7891124331240746 120.999787135136...  way_seg2_way_seg4
# 12  POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg1
# 13  POLYGON ((24.7891009999999987 120.999807300000...  way_seg0_way_seg2
# 14  POLYGON ((24.7891098135967489 120.999785598138...  way_seg1_way_seg3
# 15  POLYGON ((24.7890921864001221 120.999829001858...  way_seg2_way_seg4
#
#    way_name
# 0      環校道路
# 1      環校道路
# 2      環校道路
# 3      環校道路
# 4
# 5
# 6
# 7
# 8      環校道路
# 9      環校道路
# 10     環校道路
# 11     環校道路
# 12
# 13
# 14
# 15
# <class 'shapely.geometry.polygon.Polygon'>
# POLYGON ((24.789101 120.9998073, 24.7891022 120.9998576, 24.78912377624566 120.9998569754645, 24.78912257624565 120.9998066754645, 24.789101 120.9998073))
# [(24.789101, 120.9998073), (24.7891022, 120.9998576), (24.789123776245656, 120.99985697546447), (24.789122576245653, 120.99980667546447), (24.789101, 120.9998073)]
# [{lat: 24.789101, lng: 120.9998073}, {lat: 24.
, {lat: 24.789101, lng: 120.9998073}]
# <class 'shapely.geometry.polygon.Polygon'>
# POLYGON ((24.789101 120.9998073, 24.7892595 120.9998854, 24.78925068640013 120.9999071018864, 24.78909218640012 120.9998290018586, 24.789101 120.9998073))
# [(24.789101, 120.9998073), (24.7892595, 120.9998854), (24.789250686400127, 120.99990710188638), (24.789092186400122, 120.99982900185864), (24.789101, 120.9998073)]
# [{lat: 24.789101, lng: 120.9998073}, {lat: 24.7892595, lng: 120.9998854}, {lat: 24.789250686400127, lng: 120.99990710188638}, {lat: 24.789092186400122, lng: 120.99982900185864}, {lat: 24.789101, lng: 120.9998073}]
# <class 'shapely.geometry.polygon.Polygon'>
# POLYGON ((24.78910981359675 120.9997855981383, 24.78926831359674 120.9998636981105, 24.78927418932618 120.9998492301825, 24.78911568932617 120.9997711302286, 24.78910981359675 120.9997855981383))
# [(24.78910981359675, 120.99978559813826), (24.789268313596743, 120.99986369811052), (24.78927418932618, 120.99984923018246), (24.789115689326174, 120.99977113022862), (24.78910981359675, 120.99978559813826)]
# [{lat: 24.78910981359675, lng: 120.99978559813826}, {lat: 24.789268313596743, lng: 120.99986369811052}, {lat: 24.78927418932618, lng: 120.99984923018246}, {lat: 24.789115689326174, lng: 120.99977113022862}, {lat: 24.78910981359675, lng: 120.99978559813826}]
# <class 'shapely.geometry.polygon.Polygon'>
# POLYGON ((24.78909218640012 120.9998290018586, 24.78925068640013 120.9999071018864, 24.78924481066514 120.999921569809, 24.78908631066514 120.9998434697628, 24.78909218640012 120.9998290018586))
# [(24.789092186400122, 120.99982900185864), (24.789250686400127, 120.99990710188638), (24.789244810665142, 120.99992156980898), (24.789086310665137, 120.99984346976282), (24.789092186400122, 120.99982900185864)]
# [{lat: 24.789092186400122, lng: 120.99982900185864}, {lat: 24.789250686400127, lng: 120.99990710188638}, {lat: 24.789244810665142, lng: 120.99992156980898}, {lat: 24.789086310665137, lng: 120.99984346976282}, {lat: 24.789092186400122, lng: 120.99982900185864}]

# %%
paa_results = [{'computed_area_tan': (0, 0), 'arc': 0}, {'computed_area_tan': (0, 0), 'arc': 0}]

x = 0
for i in range(1, len(ue_logs)):
    if i % 12 == 0:
        x = i
    uii.process_ue_location(i, ue_logs[x], ue_logs[i], paa_results)
    input(suave)
# Out:
# var wayclip_3_ue14 = new google.maps.Polygon({path: [[{lat: 24.78793845039453, lng: 120.99873472725713}, {lat: 24.787939019545664, lng: 120.9987340076259}, {lat: 24.787940385865806, lng: 120.998732098461}, {lat: 24.787941665492838, lng: 120.9987301177498}, {lat: 24.787942855344006, lng: 120.99872807026418}, {lat: 24.787943952552858, lng: 120.99872596093644}, {lat: 24.78794495447612, lng: 120.99872379484839}, {lat: 24.787945858700073, lng: 120.99872157721825}, {lat: 24.78794640200882, lng: 120.99872004807763}, {lat: 24.787943374565806, lng: 120.99871565182076}, {lat: 24.787919792649785, lng: 120.99870763368591}, {lat: 24.78793845039453, lng: 120.99873472725713}], [{lat: 24.787907603236203, lng: 120.99868993300721}, {lat: 24.78791251067198, lng: 120.99867083327104}, {lat: 24.787900293682377, lng: 120.99865309254918}, {lat: 24.787899155473553, lng: 120.99865320866752}, {lat: 24.787896970470754, lng: 120.99865355137331}, {lat: 24.78789480336636, lng: 120.99865401175975}, {lat: 24.78789265938111, lng: 120.99865458871773}, {lat: 24.787890543680057, lng: 120.99865528085718}, {lat: 24.787888461360108, lng: 120.99865608651066}, {lat: 24.787886417437747, lng: 120.99865700373743}, {lat: 24.787885316003702, lng: 120.99865756892842}, {lat: 24.787907603236203, lng: 120.99868993300721}]], geodesic: true, strokeColor:
# var wayclip_1_ue15 = new google.maps.Polygon({path: [[{lat: 24.787748119462094, lng: 120.99849427247226}, {lat: 24.787748865492837, lng: 120.99849311770674}, {lat: 24.787750055344013, lng: 120.99849107022419}, {lat: 24.78775115255286, lng: 120.99848896089986}, {lat: 24.787752154476127, lng: 120.99848679481511}, {lat: 24.787753058700076, lng: 120.99848457718838}, {lat: 24.787753863046355, lng: 120.99848231336205}, {lat: 24.787754565577224, lng: 120.99848000879001}, {lat: 24.787733136000046, lng: 120.9984727224875}, {lat: 24.787748119462094, lng: 120.99849427247226}], [{lat: 24.787716037262467, lng: 120.99844813020482}, {lat: 24.787723372880734, lng: 120.99841958002865}, {lat: 24.787721669061543, lng: 120.99841712950857}, {lat: 24.7877195451651, lng: 120.99841664999735}, {lat: 24.78771736393123, lng: 120.9984162793055}, {lat: 24.78771516881156, lng: 120.99841602694971}, {lat: 24.787712965094325, lng: 120.99841589353787}, {lat: 24.787710758088487, lng: 120.99841587939159}, {lat: 24.787708553110896, lng: 120.99841598454464}, {lat: 24.787706355473556, lng: 120.99841620874395}, {lat: 24.787704170470757, lng: 120.99841655144928}, {lat: 24.78770200336636, lng: 120.99841701183493}, {lat: 24.787699859381117, lng: 120.998417588792}, {lat: 24.787697743680063, lng: 120.99841828093042}, {lat: 24.78769580493563, lng: 120.99841903103311}, {lat: 24.787716037262467, lng: 120.99844813020482}]], geodesic: true, strokeColor:

# %%
paa_results = [{'computed_area_tan': (0, 0), 'arc': 0, 'paa_gdf': geopandas.GeoDataFrame()}, {'computed_area_tan': (0, 0), 'arc': 0, 'paa_gdf': geopandas.GeoDataFrame()}]
x = 0
for i in range(1, len(ue_logs)):
    if i % 12 == 0:
        x = i
    aa, b, c = uii.process_ue_location(i, ue_logs[x], ue_logs[i], paa_results)
    
    plt.show()
    input('suave')
    continue
    
    
    for a in aa:
        clipped = geopandas.clip(b, a)
        fig, ax = plt.subplots(figsize=(12, 8))
        a.boundary.plot(ax=ax)
        b.boundary.plot(ax=ax, color='green')
        clipped.plot(ax=ax, color='purple')
        print(clipped)
        if clipped.area.size > 0:
            print(clipped.area.iloc[0], c)
        print('******************************************************')
        plt.show()
        input('next')
    print('END OF DOUBLE A')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7c1467eeeb3f> in <module>
#       4     if i % 12 == 0:
#       5         x = i
# ----> 6     aa, b, c = uii.process_ue_location(i, ue_logs[x], ue_logs[i], paa_results)
#       7
#       8     plt.show()
#
# TypeError: 'bool' object is not iterable
